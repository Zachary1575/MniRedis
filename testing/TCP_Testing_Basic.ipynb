# %%
import socket
import random

# %%
'''
Function to create a client TCP socket
'''
def createClientTCPSocket(address, port):
    clientsocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    clientsocket.connect((address, port))
    return clientsocket

''' 
Function to send data
'''
def sendDataFromTCPSocket(clientSocket, data):
    clientSocket.send(data);
    return

# %%
# For testing out sockets and sending a bunch of data
numOfSockets = 100
socketArr = []
for x in range(numOfSockets):
    clientSocket =  createClientTCPSocket('localhost', 8080)
    socketArr.append(clientSocket)
